# %%
import pandas as pd
vegas_data = pd.read_csv('lasvegas_tripadvisor.csv')
vegas_data.head()
# Out:
#   User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 0          USA           11                  4             13      5
# 1          USA          119                 21             75      3
# 2          USA           36                  9             25      5
# 3           UK           14                  7             14      4
# 4       Canada            5                  5              2      4
#
#   Period of stay Traveler type Pool  Gym Tennis court Spa Casino  \
# 0        Dec-Feb       Friends   NO  YES           NO  NO    YES
# 1        Dec-Feb      Business   NO  YES           NO  NO    YES
# 2        Mar-May      Families   NO  YES           NO  NO    YES
# 3        Mar-May       Friends   NO  YES           NO  NO    YES
# 4        Mar-May          Solo   NO  YES           NO  NO    YES
#
#   Free internet                              Hotel name  Hotel stars  \
# 0           YES  Circus Circus Hotel & Casino Las Vegas            3
# ...

# %%
vegas_data.describe()
# Out:
#        Nr. reviews  Nr. hotel reviews  Helpful votes       Score  Hotel stars  \
# count   504.000000         504.000000     504.000000  504.000000   504.000000
# mean     48.130952          16.023810      31.751984    4.123016     4.047619
# std      74.996426          23.957953      48.520783    1.007302     0.844650
# min       1.000000           0.000000       0.000000    1.000000     3.000000
# 25%      12.000000           5.000000       8.000000    4.000000     3.000000
# 50%      23.500000           9.000000      16.000000    4.000000     4.000000
# 75%      54.250000          18.000000      35.000000    5.000000     5.000000
# max     775.000000         263.000000     365.000000    5.000000     5.000000
#
#          Nr. rooms  Member years
# count   504.000000    504.000000
# mean   2196.380952      0.767857
# std    1285.476807     80.692897
# min     188.000000  -1806.000000
# 25%     826.000000      2.000000
# 50%    2700.000000      4.000000
# ...

# %%
Number_of_Reviews = vegas_data['Nr. reviews']
Score = vegas_data['Score']
median_data = housing_data[['Score', 'Nr. reviews']]

import matplotlib.pyplot as plt
plt.figure(figsize = (20,20))
plt.ylabel('Score')
plt.xlabel('Nr. reveiws')
plt.title('Score vs Number of Reveiws')
plt.scatter(Score, Number_of_Reviews)

# %%
import numpy as np
import statsmodels.api as sm

# %%
x_ary = vegas_data['Nr. reviews']
x_with_cnst = sm.add_constant(x_ary)
model = sm.OLS(vegas_data ['Score'], x_with_cnst)
results = model.fit()
b,m = results.params
print(m)
print(b)
# Out:
# -0.00032664709544516035
# 4.138737708812123

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Score   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.2971
# Date:                Mon, 11 Jul 2022   Prob (F-statistic):              0.586
# Time:                        13:51:42   Log-Likelihood:                -718.16
# No. Observations:                 504   AIC:                             1440.
# Df Residuals:                     502   BIC:                             1449.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           4.1387      0.053     77.552      0.000       4.034       4.244
# ...

# %%
plt.figure(figsize = (20,20))
plt.scatter(housing_data['Nr. reviews'], housing_data['Score'])
plt.plot(x_ary, m*x_ary+b, color ='orange', linewidth = 4)
